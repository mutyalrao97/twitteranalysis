# %%
# Install Libraries
# !pip install textblob
# !pip install tweepy
# !pip install pycountry
# !pip install wordcloud
# !pip install langdetect
# Out:
# Collecting textblob
#   Downloading textblob-0.17.1-py2.py3-none-any.whl (636 kB)
#      -------------------------------------- 636.8/636.8 kB 4.0 MB/s eta 0:00:00
# Requirement already satisfied: nltk>=3.1 in c:\users\mutya\anaconda3\lib\site-packages (from textblob) (3.7)
# Requirement already satisfied: tqdm in c:\users\mutya\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (4.64.1)
# Requirement already satisfied: click in c:\users\mutya\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (8.0.4)
# Requirement already satisfied: joblib in c:\users\mutya\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (1.1.1)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\mutya\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (2022.7.9)
# Requirement already satisfied: colorama in c:\users\mutya\anaconda3\lib\site-packages (from click->nltk>=3.1->textblob) (0.4.6)
# Installing collected packages: textblob
# Successfully installed textblob-0.17.1
# Collecting tweepy
#   Downloading tweepy-4.14.0-py3-none-any.whl (98 kB)
#      -------------------------------------- 98.5/98.5 kB 939.1 kB/s eta 0:00:00
# Collecting oauthlib<4,>=3.2.0
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      -------------------------------------- 151.7/151.7 kB 3.0 MB/s eta 0:00:00
# Collecting requests-oauthlib<2,>=1.2.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: requests<3,>=2.27.0 in c:\users\mutya\anaconda3\lib\site-packages (from tweepy) (2.28.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\mutya\anaconda3\lib\site-packages (from requests<3,>=2.27.0->tweepy) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mutya\anaconda3\lib\site-packages (from requests<3,>=2.27.0->tweepy) (2022.12.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\mutya\anaconda3\lib\site-packages (from requests<3,>=2.27.0->tweepy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mutya\anaconda3\lib\site-packages (from requests<3,>=2.27.0->tweepy) (3.4)
# Installing collected packages: oauthlib, requests-oauthlib, tweepy
# Successfully installed oauthlib-3.2.2 requests-oauthlib-1.3.1 tweepy-4.14.0
# Collecting pycountry
#   Downloading pycountry-22.3.5.tar.gz (10.1 MB)
#      ---------------------------------------- 10.1/10.1 MB 5.4 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: setuptools in c:\users\mutya\anaconda3\lib\site-packages (from pycountry) (65.6.3)
# Building wheels for collected packages: pycountry
#   Building wheel for pycountry (pyproject.toml): started
#   Building wheel for pycountry (pyproject.toml): finished with status 'done'
#   Created wheel for pycountry: filename=pycountry-22.3.5-py2.py3-none-any.whl size=10681896 sha256=5e47739fd4a0471628767e2eb41c143dcabd160a59bd4bd0355acca05876e062
#   Stored in directory: c:\users\mutya\appdata\local\pip\cache\wheels\62\4a\9c\7a46699df9efb845aa116fae5e52d8690fc442fef6d32213f7
# Successfully built pycountry
# Installing collected packages: pycountry
# Successfully installed pycountry-22.3.5
# Collecting wordcloud
#   Downloading wordcloud-1.9.1.1-cp310-cp310-win_amd64.whl (152 kB)
#      -------------------------------------- 152.1/152.1 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.6.1 in c:\users\mutya\anaconda3\lib\site-packages (from wordcloud) (1.23.5)
# Requirement already satisfied: pillow in c:\users\mutya\anaconda3\lib\site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: matplotlib in c:\users\mutya\anaconda3\lib\site-packages (from wordcloud) (3.7.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\mutya\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\mutya\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\mutya\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\mutya\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\mutya\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\mutya\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\mutya\anaconda3\lib\site-packages (from matplotlib->wordcloud) (22.0)
# Requirement already satisfied: six>=1.5 in c:\users\mutya\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.1.1
# Collecting langdetect
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      -------------------------------------- 981.5/981.5 kB 2.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: six in c:\users\mutya\anaconda3\lib\site-packages (from langdetect) (1.16.0)
# Building wheels for collected packages: langdetect
#   Building wheel for langdetect (setup.py): started
#   Building wheel for langdetect (setup.py): finished with status 'done'
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993253 sha256=56646b0fe38050bdcd10b59bbc44ff0c340a5062ae6dc53c037c3c7f40286625
#   Stored in directory: c:\users\mutya\appdata\local\pip\cache\wheels\c4\16\af\1889804d8b7c0c041cadee8e29673a938a332acbf2865c70a1
# Successfully built langdetect
# Installing collected packages: langdetect
# Successfully installed langdetect-1.0.9

# %%
# Import Libraries

from textblob import TextBlob
import sys
import tweepy
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
import nltk
import pycountry
import re
import string
from wordcloud import WordCloud, STOPWORDS
from PIL import Image
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from langdetect import detect
from nltk.stem import SnowballStemmer
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from sklearn.feature_extraction.text import CountVectorizer
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\mutya\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %% [markdown]
# # Step 2: Authentication for Twitter API

# %%
# Authentication
consumerKey = "2CJbp8m7Rg26LtZEKAeVXWceG"
consumerSecret = "IbULWKlS0uvhLnMTcFkzvMjDfZUcBM6eVbdLYMUbNafhieX8Y6"
accessToken = "1119095264961126402-8QDK0FvTjGmV7w1hUtGsTyCyH77bNE"
accessTokenSecret = "unheMaBnZsHrcBt3mK1bE8Ib4wtE3tPtAwSA65Y0zWIK0"

auth = tweepy.OAuthHandler(consumerKey, consumerSecret)
auth.set_access_token(accessToken, accessTokenSecret)
api = tweepy.API(auth)

# %% [markdown]
# # Step 3: Getting Tweets With Keyword or Hashtag

# %%
#Sentiment Analysis
def percentage(part,whole):
    return 100 * float(part)/float(whole) 

keyword = input("Please enter keyword or hashtag to search: ")
noOfTweet = int(input ("Please enter how many tweets to analyze: "))

tweets = tweepy.Cursor(api.search_tweets, q=keyword).items(noOfTweet)
positive  = 0
negative = 0
neutral = 0
polarity = 0
tweet_list = []
neutral_list = []
negative_list = []
positive_list = []

for tweet in tweets:
    # print(tweet.text)
    tweet_list.append(tweet.text)
    analysis = TextBlob(tweet.text)
    score = SentimentIntensityAnalyzer().polarity_scores(tweet.text)
    neg = score['neg']
    neu = score['neu']
    pos = score['pos']
    comp = score['compound']
    polarity += analysis.sentiment.polarity
    
    if neg > pos:
        negative_list.append(tweet.text)
        negative += 1

    elif pos > neg:
        positive_list.append(tweet.text)
        positive += 1
    
    elif pos == neg:
        neutral_list.append(tweet.text)
        neutral += 1

positive = percentage(positive, noOfTweet)
negative = percentage(negative, noOfTweet)
neutral = percentage(neutral, noOfTweet)
polarity = percentage(polarity, noOfTweet)
positive = format(positive, '.1f')
negative = format(negative, '.1f')
neutral = format(neutral, '.1f')
# Out:
# Please enter keyword or hashtag to search: UCM
# Please enter how many tweets to analyze: 172

# %%
#Number of Tweets (Total, Positive, Negative, Neutral)
tweet_list = pd.DataFrame(tweet_list)
neutral_list = pd.DataFrame(neutral_list)
negative_list = pd.DataFrame(negative_list)
positive_list = pd.DataFrame(positive_list)
print("total number: ",len(tweet_list))
print("positive number: ",len(positive_list))
print("negative number: ", len(negative_list))
print("neutral number: ",len(neutral_list))
# Out:
# total number:  47
# positive number:  31
# negative number:  89
# neutral number:  52

# %%
tweet_list[0:20]
# Out:
#                                                     0  \
# 0   RT @MarvelLatin: Top 5 VILLANOS del UCM https:...
# 1   RT @GabyMeza8: ¡EN HONOR A STAR WARS! 🙌 Por el...
# 4   Cómo voy a ponerme a pensar en otras historias...
# 5   RT @peterjordan100: Geral falando bem de Guard...
# 7   RT @Multiverso_GK: Y así cierra, una de las me...
# 8   Por el #MayThe4thBeWithYou, #JamesGunn publicó...
# 9   @RonalGames117 La 2 me conmovió mil veces más ...
# 12  Guardianes de la galaxia 3 es una montaña rusa...
# 14  DC con James Gunn logrará darle la vuelta y su...
# 21  Increíblemente emotiva, desprende una sensació...
# 24  @lauramorata_ @toddedillard Sí, pero no es por...
# 29  ES LA MEJOR, UNA DE MIS FAVORITAS DEL UCM 👏🏼❤️...
# 30  👉🏻 Después de #DoctorStrangeInTheMultiverseOMa...
# 36  @elianchico9070 @Soy_Sense @MarvelLatin Porqué...
# 40  RT @YulierSarria: En la #UCM de #Cienfuegos se...
# 44  RT @lpuchg: Afiliación a la Seguridad Social e...
# 48  Guardianes de la Galaxia Vol. 3 llego para dar...
# 52  ¿A ti también te preocupa la #IA? ¿Por qué no ...
# 54  RT @Ian4Star: Bueno señores hoy toca ver #Guar...
# 55  RT @MarvelDato: 🍿 | ¿Del 1 al 10, qué notan le...
#
#                                                  text  polarity  subjectivity  \
# 0                            top 5 villanos del ucm    0.500000      0.500000
# 1     en honor a star wars    por el  maythe4thbew...  0.000000      0.066667
# 4   c mo voy a ponerme a pensar en otras historias...  0.000000      0.000000
# 5    geral falando bem de guardi es da gal xia  ge...  0.000000      0.000000
# 7    y as  cierra  una de las mejores trilog as de...  0.000000      0.000000
# 8   por el  maythe4thbewithyou   jamesgunn public ...  0.000000      0.066667
# 9     la 2 me conmovi  mil veces m s que cualquier...  0.000000      0.000000
# 12  guardianes de la galaxia 3 es una monta a rusa...  0.000000      0.000000
# 14  dc con james gunn lograr  darle la vuelta y su...  0.000000      0.000000
# 21  incre blemente emotiva  desprende una sensaci ...  0.000000      0.000000
# 24       s   pero no es por la poes a  es culpa de...  0.000000      0.000000
# 29  es la mejor  una de mis favoritas del ucm          0.000000      0.000000
# 30     despu s de  doctorstrangeinthemultiverseoma...  0.000000      0.000000
# 36      sense   porqu  no  a fin de cuentas estuvo...  0.000000      0.000000
# 40   en la  ucm de  cienfuegos se realiz  en la ma...  0.000000      0.000000
# 44   afiliaci n a la seguridad social en datos dia...  0.033333      0.066667
# 48  guardianes de la galaxia vol  3 llego para dar...  0.000000      0.000000
# 52   a ti tambi n te preocupa la  ia   por qu  no ...  0.000000      0.000000
# 54   bueno se ores hoy toca ver  guardiansofthegal...  0.000000      0.000000
# 55        del 1 al 10  qu  notan le ponen a  guard...  0.000000      0.000000
#
#    sentiment    neg    neu    pos  compound
# 0   positive  0.000  0.625  0.375    0.2023
# 1   negative  0.165  0.688  0.147   -0.1027
# 4    neutral  0.000  1.000  0.000    0.0000
# 5    neutral  0.000  1.000  0.000    0.0000
# 7    neutral  0.000  1.000  0.000    0.0000
# 8    neutral  0.000  1.000  0.000    0.0000
# 9    neutral  0.000  1.000  0.000    0.0000
# 12   neutral  0.000  1.000  0.000    0.0000
# 14  positive  0.000  0.897  0.103    0.3400
# 21   neutral  0.000  1.000  0.000    0.0000
# 24  negative  0.180  0.820  0.000   -0.2960
# 29   neutral  0.000  1.000  0.000    0.0000
# 30   neutral  0.000  1.000  0.000    0.0000
# 36  negative  0.196  0.804  0.000   -0.2960
# 40   neutral  0.000  1.000  0.000    0.0000
# 44  negative  0.159  0.841  0.000   -0.5574
# 48   neutral  0.000  1.000  0.000    0.0000
# 52  negative  0.128  0.872  0.000   -0.2960
# 54   neutral  0.000  1.000  0.000    0.0000
# 55   neutral  0.000  1.000  0.000    0.0000

# %%
#Creating PieCart

labels = ['Positive ['+str(positive)+'%]' , 'Neutral ['+str(neutral)+'%]','Negative ['+str(negative)+'%]']
sizes = [positive, neutral, negative]
colors = ['yellowgreen', 'blue','red']
patches, texts = plt.pie(sizes,colors=colors, startangle=90)
plt.style.use('default')
plt.legend(labels)
plt.title("Sentiment Analysis Result for keyword=  "+keyword+"" )
plt.axis('equal')
plt.show()

# %%
tweet_list.drop_duplicates(inplace = True)

# %% [markdown]
# # Extracting text values

# %%
tw_list = pd.DataFrame(tweet_list)
tw_list["text"] = tw_list[0]
tw_list
# Out:
#                                                      0  \
# 0    RT @MarvelLatin: Top 5 VILLANOS del UCM https:...
# 1    RT @GabyMeza8: ¡EN HONOR A STAR WARS! 🙌 Por el...
# 4    Cómo voy a ponerme a pensar en otras historias...
# 5    RT @peterjordan100: Geral falando bem de Guard...
# 7    RT @Multiverso_GK: Y así cierra, una de las me...
# 8    Por el #MayThe4thBeWithYou, #JamesGunn publicó...
# 9    @RonalGames117 La 2 me conmovió mil veces más ...
# 12   Guardianes de la galaxia 3 es una montaña rusa...
# 14   DC con James Gunn logrará darle la vuelta y su...
# 21   Increíblemente emotiva, desprende una sensació...
# 24   @lauramorata_ @toddedillard Sí, pero no es por...
# 29   ES LA MEJOR, UNA DE MIS FAVORITAS DEL UCM 👏🏼❤️...
# 30   👉🏻 Después de #DoctorStrangeInTheMultiverseOMa...
# 36   @elianchico9070 @Soy_Sense @MarvelLatin Porqué...
# 40   RT @YulierSarria: En la #UCM de #Cienfuegos se...
# 44   RT @lpuchg: Afiliación a la Seguridad Social e...
# 48   Guardianes de la Galaxia Vol. 3 llego para dar...
# 52   ¿A ti también te preocupa la #IA? ¿Por qué no ...
# 54   RT @Ian4Star: Bueno señores hoy toca ver #Guar...
# 55   RT @MarvelDato: 🍿 | ¿Del 1 al 10, qué notan le...
# 56   @AgentedeMarvel_ Otra película totalmente mach...
# 60   @ArgieViBritania Sin temblarme el pulso diría ...
# 64   RT @julieta_aramayo: @_NovelaGrafica Para mí s...
# 75   @J4viiKal Con Quantumania es cuando dije "hast...
# 78   @EnriiqueM_ Ay Dios… pa mi es la trilogía más ...
# 80   RT @MarvelLatin: Luego de analizarlo\n\n#Guard...
# 82   #GuardiansOfTheGalaxyVol3 es un PELICULÓN, me ...
# 83   RT @AndresEHernnde1: En Villa Clara hoy defien...
# 90   ¡Gracias! El lunes iniciaremos clases de esta ...
# 96   RT @lpuchg: @Raulsees @darioserranopue @nadaes...
# 101  @MarvelLatin Top 5 VILLANOS del UCM https://t....
# 108  Esta película de los guardianes de la galaxia ...
# 110  @Renasnormal Eu imagino algo assim só que ao i...
# 122  La trilogía de Marvel que empecé en Murcia y c...
# 129  RT @JuanMLemus1: UCM PINAR DEL RÍO.           ...
# 134  Guardiões da Galáxia Vol. 3 promete subir o ní...
# 140  RT @guilleuu1: Abro hilo: 🦠7 MITOS SOBRE EL VP...
# 141  Discusión Final de Tesis de Dotorado del MSc. ...
# 142  #GuardiansoftheGalaxyVol3  es una obra maestra...
# 144  EN HONOR A STAR WARS! 🙌 Por el #MayThe4thBeWit...
# 146  Jueves de estrenos en cines (4/5/23):\n\n- "Gu...
# 151  RT @TdpSexy: No es ni de lejos la mejor pelícu...
# 152  RT @JcsMadrid_: ¿Te perdiste la participación ...
# 153  En la #UCM de #Cienfuegos se realizó en la mañ...
# 155  Merecido homenaje en la RANF a César Nombela C...
# 164  Estudio de grupo MOMAT del Instituto de Matemá...
# 170  @ocram Exacto! Qué otro gran director queda en...
#
#                                                   text  polarity  \
# 0    RT @MarvelLatin: Top 5 VILLANOS del UCM https:...  0.500000
# 1    RT @GabyMeza8: ¡EN HONOR A STAR WARS! 🙌 Por el...  0.000000
# 4    Cómo voy a ponerme a pensar en otras historias...  0.000000
# 5    RT @peterjordan100: Geral falando bem de Guard...  0.000000
# 7    RT @Multiverso_GK: Y así cierra, una de las me...  0.000000
# 8    Por el #MayThe4thBeWithYou, #JamesGunn publicó...  0.000000
# 9    @RonalGames117 La 2 me conmovió mil veces más ...  0.000000
# 12   Guardianes de la galaxia 3 es una montaña rusa...  0.000000
# 14   DC con James Gunn logrará darle la vuelta y su...  0.000000
# 21   Increíblemente emotiva, desprende una sensació...  0.000000
# 24   @lauramorata_ @toddedillard Sí, pero no es por...  0.000000
# 29   ES LA MEJOR, UNA DE MIS FAVORITAS DEL UCM 👏🏼❤️...  0.000000
# 30   👉🏻 Después de #DoctorStrangeInTheMultiverseOMa...  0.000000
# 36   @elianchico9070 @Soy_Sense @MarvelLatin Porqué...  0.000000
# 40   RT @YulierSarria: En la #UCM de #Cienfuegos se...  0.000000
# 44   RT @lpuchg: Afiliación a la Seguridad Social e...  0.033333
# 48   Guardianes de la Galaxia Vol. 3 llego para dar...  0.000000
# 52   ¿A ti también te preocupa la #IA? ¿Por qué no ...  0.000000
# 54   RT @Ian4Star: Bueno señores hoy toca ver #Guar...  0.000000
# 55   RT @MarvelDato: 🍿 | ¿Del 1 al 10, qué notan le...  0.000000
# 56   @AgentedeMarvel_ Otra película totalmente mach... -1.000000
# 60   @ArgieViBritania Sin temblarme el pulso diría ...  0.000000
# 64   RT @julieta_aramayo: @_NovelaGrafica Para mí s...  0.000000
# 75   @J4viiKal Con Quantumania es cuando dije "hast...  0.000000
# 78   @EnriiqueM_ Ay Dios… pa mi es la trilogía más ...  0.000000
# 80   RT @MarvelLatin: Luego de analizarlo\n\n#Guard...  0.000000
# 82   #GuardiansOfTheGalaxyVol3 es un PELICULÓN, me ...  0.000000
# 83   RT @AndresEHernnde1: En Villa Clara hoy defien...  0.000000
# 90   ¡Gracias! El lunes iniciaremos clases de esta ...  0.000000
# 96   RT @lpuchg: @Raulsees @darioserranopue @nadaes...  0.000000
# 101  @MarvelLatin Top 5 VILLANOS del UCM https://t....  0.500000
# 108  Esta película de los guardianes de la galaxia ...  0.000000
# 110  @Renasnormal Eu imagino algo assim só que ao i...  0.000000
# 122  La trilogía de Marvel que empecé en Murcia y c...  0.000000
# 129  RT @JuanMLemus1: UCM PINAR DEL RÍO.           ...  0.000000
# 134  Guardiões da Galáxia Vol. 3 promete subir o ní...  0.000000
# 140  RT @guilleuu1: Abro hilo: 🦠7 MITOS SOBRE EL VP...  0.000000
# 141  Discusión Final de Tesis de Dotorado del MSc. ...  0.000000
# 142  #GuardiansoftheGalaxyVol3  es una obra maestra...  0.000000
# 144  EN HONOR A STAR WARS! 🙌 Por el #MayThe4thBeWit...  0.000000
# 146  Jueves de estrenos en cines (4/5/23):\n\n- "Gu...  0.000000
# 151  RT @TdpSexy: No es ni de lejos la mejor pelícu...  0.000000
# 152  RT @JcsMadrid_: ¿Te perdiste la participación ...  0.000000
# 153  En la #UCM de #Cienfuegos se realizó en la mañ...  0.000000
# 155  Merecido homenaje en la RANF a César Nombela C...  0.000000
# 164  Estudio de grupo MOMAT del Instituto de Matemá...  0.000000
# 170  @ocram Exacto! Qué otro gran director queda en...  0.000000
#
#      subjectivity sentiment    neg    neu    pos  compound
# 0        0.500000  positive  0.000  0.625  0.375    0.2023
# 1        0.066667  negative  0.165  0.688  0.147   -0.1027
# 4        0.000000   neutral  0.000  1.000  0.000    0.0000
# 5        0.000000   neutral  0.000  1.000  0.000    0.0000
# 7        0.000000   neutral  0.000  1.000  0.000    0.0000
# 8        0.066667   neutral  0.000  1.000  0.000    0.0000
# 9        0.000000   neutral  0.000  1.000  0.000    0.0000
# 12       0.000000   neutral  0.000  1.000  0.000    0.0000
# 14       0.000000  positive  0.000  0.897  0.103    0.3400
# 21       0.000000   neutral  0.000  1.000  0.000    0.0000
# 24       0.000000  negative  0.180  0.820  0.000   -0.2960
# 29       0.000000   neutral  0.000  1.000  0.000    0.0000
# 30       0.000000   neutral  0.000  1.000  0.000    0.0000
# 36       0.000000  negative  0.196  0.804  0.000   -0.2960
# 40       0.000000   neutral  0.000  1.000  0.000    0.0000
# 44       0.066667  negative  0.159  0.841  0.000   -0.5574
# 48       0.000000   neutral  0.000  1.000  0.000    0.0000
# 52       0.000000  negative  0.128  0.872  0.000   -0.2960
# 54       0.000000   neutral  0.000  1.000  0.000    0.0000
# 55       0.000000   neutral  0.000  1.000  0.000    0.0000
# 56       1.000000  negative  0.336  0.664  0.000   -0.7964
# 60       0.000000  negative  0.217  0.783  0.000   -0.5574
# 64       0.000000   neutral  0.000  1.000  0.000    0.0000
# 75       0.000000  positive  0.000  0.859  0.141    0.4215
# 78       0.000000   neutral  0.000  1.000  0.000    0.0000
# 80       0.000000   neutral  0.000  1.000  0.000    0.0000
# 82       0.000000  negative  0.190  0.690  0.121   -0.1531
# 83       0.000000   neutral  0.000  1.000  0.000    0.0000
# 90       0.000000   neutral  0.000  1.000  0.000    0.0000
# 96       0.000000  negative  0.474  0.526  0.000   -0.5574
# 101      0.500000  positive  0.000  0.625  0.375    0.2023
# 108      0.000000  positive  0.000  0.809  0.191    0.6369
# 110      0.000000  positive  0.000  0.843  0.157    0.4215
# 122      0.000000  positive  0.000  0.877  0.123    0.4215
# 129      0.000000   neutral  0.000  1.000  0.000    0.0000
# 134      0.000000  positive  0.092  0.792  0.117    0.1531
# 140      0.000000   neutral  0.000  1.000  0.000    0.0000
# 141      1.000000  positive  0.000  0.884  0.116    0.3612
# 142      0.000000   neutral  0.000  1.000  0.000    0.0000
# 144      0.066667  negative  0.191  0.638  0.170   -0.1027
# 146      1.000000   neutral  0.000  1.000  0.000    0.0000
# 151      0.000000  negative  0.180  0.745  0.075   -0.5267
# 152      0.000000   neutral  0.000  1.000  0.000    0.0000
# 153      0.000000   neutral  0.000  1.000  0.000    0.0000
# 155      0.000000   neutral  0.000  1.000  0.000    0.0000
# 164      0.000000   neutral  0.000  1.000  0.000    0.0000
# 170      0.000000   neutral  0.000  1.000  0.000    0.0000

# %%
#Cleaning Text (RT, Punctuation etc)

#Creating new dataframe and new features
tw_list = pd.DataFrame(tweet_list)
tw_list["text"] = tw_list[0]

#Removing RT, Punctuation etc
remove_rt = lambda x: re.sub('RT @\w+: '," ",x)
rt = lambda x: re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ",x)
tw_list["text"] = tw_list.text.map(remove_rt).map(rt)
tw_list["text"] = tw_list.text.str.lower()
tw_list.head(10)
# Out:
#                                                     0  \
# 0   RT @MarvelLatin: Top 5 VILLANOS del UCM https:...
# 1   RT @GabyMeza8: ¡EN HONOR A STAR WARS! 🙌 Por el...
# 4   Cómo voy a ponerme a pensar en otras historias...
# 5   RT @peterjordan100: Geral falando bem de Guard...
# 7   RT @Multiverso_GK: Y así cierra, una de las me...
# 8   Por el #MayThe4thBeWithYou, #JamesGunn publicó...
# 9   @RonalGames117 La 2 me conmovió mil veces más ...
# 12  Guardianes de la galaxia 3 es una montaña rusa...
# 14  DC con James Gunn logrará darle la vuelta y su...
# 21  Increíblemente emotiva, desprende una sensació...
#
#                                                  text  polarity  subjectivity  \
# 0                            top 5 villanos del ucm         0.5      0.500000
# 1     en honor a star wars    por el  maythe4thbew...       0.0      0.066667
# 4   c mo voy a ponerme a pensar en otras historias...       0.0      0.000000
# 5    geral falando bem de guardi es da gal xia  ge...       0.0      0.000000
# 7    y as  cierra  una de las mejores trilog as de...       0.0      0.000000
# 8   por el  maythe4thbewithyou   jamesgunn public ...       0.0      0.066667
# 9     la 2 me conmovi  mil veces m s que cualquier...       0.0      0.000000
# 12  guardianes de la galaxia 3 es una monta a rusa...       0.0      0.000000
# 14  dc con james gunn lograr  darle la vuelta y su...       0.0      0.000000
# 21  incre blemente emotiva  desprende una sensaci ...       0.0      0.000000
#
#    sentiment    neg    neu    pos  compound
# 0   positive  0.000  0.625  0.375    0.2023
# 1   negative  0.165  0.688  0.147   -0.1027
# 4    neutral  0.000  1.000  0.000    0.0000
# 5    neutral  0.000  1.000  0.000    0.0000
# 7    neutral  0.000  1.000  0.000    0.0000
# 8    neutral  0.000  1.000  0.000    0.0000
# 9    neutral  0.000  1.000  0.000    0.0000
# 12   neutral  0.000  1.000  0.000    0.0000
# 14  positive  0.000  0.897  0.103    0.3400
# 21   neutral  0.000  1.000  0.000    0.0000

# %%
#Calculating Negative, Positive, Neutral and Compound values

tw_list[['polarity', 'subjectivity']] = tw_list['text'].apply(lambda Text: pd.Series(TextBlob(Text).sentiment))
for index, row in tw_list['text'].iteritems():
    score = SentimentIntensityAnalyzer().polarity_scores(row)
    neg = score['neg']
    neu = score['neu']
    pos = score['pos']
    comp = score['compound']
    if neg > pos:
        tw_list.loc[index, 'sentiment'] = "negative"
    elif pos > neg:
        tw_list.loc[index, 'sentiment'] = "positive"
    else:
        tw_list.loc[index, 'sentiment'] = "neutral"
    tw_list.loc[index, 'neg'] = neg
    tw_list.loc[index, 'neu'] = neu
    tw_list.loc[index, 'pos'] = pos
    tw_list.loc[index, 'compound'] = comp

tw_list.head(10)
# Out:
# C:\Users\mutya\AppData\Local\Temp\ipykernel_24240\4219357815.py:4: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for index, row in tw_list['text'].iteritems():
#                                                     0  \
# 0   RT @MarvelLatin: Top 5 VILLANOS del UCM https:...
# 1   RT @GabyMeza8: ¡EN HONOR A STAR WARS! 🙌 Por el...
# 4   Cómo voy a ponerme a pensar en otras historias...
# 5   RT @peterjordan100: Geral falando bem de Guard...
# 7   RT @Multiverso_GK: Y así cierra, una de las me...
# 8   Por el #MayThe4thBeWithYou, #JamesGunn publicó...
# 9   @RonalGames117 La 2 me conmovió mil veces más ...
# 12  Guardianes de la galaxia 3 es una montaña rusa...
# 14  DC con James Gunn logrará darle la vuelta y su...
# 21  Increíblemente emotiva, desprende una sensació...
#
#                                                  text  polarity  subjectivity  \
# 0                            top 5 villanos del ucm         0.5      0.500000
# 1     en honor a star wars    por el  maythe4thbew...       0.0      0.066667
# 4   c mo voy a ponerme a pensar en otras historias...       0.0      0.000000
# 5    geral falando bem de guardi es da gal xia  ge...       0.0      0.000000
# 7    y as  cierra  una de las mejores trilog as de...       0.0      0.000000
# 8   por el  maythe4thbewithyou   jamesgunn public ...       0.0      0.066667
# 9     la 2 me conmovi  mil veces m s que cualquier...       0.0      0.000000
# 12  guardianes de la galaxia 3 es una monta a rusa...       0.0      0.000000
# 14  dc con james gunn lograr  darle la vuelta y su...       0.0      0.000000
# 21  incre blemente emotiva  desprende una sensaci ...       0.0      0.000000
#
#    sentiment    neg    neu    pos  compound
# 0   positive  0.000  0.625  0.375    0.2023
# 1   negative  0.165  0.688  0.147   -0.1027
# 4    neutral  0.000  1.000  0.000    0.0000
# 5    neutral  0.000  1.000  0.000    0.0000
# 7    neutral  0.000  1.000  0.000    0.0000
# 8    neutral  0.000  1.000  0.000    0.0000
# 9    neutral  0.000  1.000  0.000    0.0000
# 12   neutral  0.000  1.000  0.000    0.0000
# 14  positive  0.000  0.897  0.103    0.3400
# 21   neutral  0.000  1.000  0.000    0.0000

# %%
#Creating new data frames for all sentiments (positive, negative and neutral)

tw_list_negative = tw_list[tw_list["sentiment"]=="negative"]
tw_list_positive = tw_list[tw_list["sentiment"]=="positive"]
tw_list_neutral = tw_list[tw_list["sentiment"]=="neutral"]

# %%
#Function for count_values_in single columns

def count_values_in_column(data,feature):
    total=data.loc[:,feature].value_counts(dropna=False)
    percentage=round(data.loc[:,feature].value_counts(dropna=False,normalize=True)*100,2)
    return pd.concat([total,percentage],axis=1,keys=['Total','Percentage'])

# %%
#Count_values for sentiment
count_values_in_column(tw_list,"sentiment")
# Out:
#           Total  Percentage
# neutral      27       57.45
# negative     11       23.40
# positive      9       19.15

# %%
# create data for Pie Chart
pc = count_values_in_column(tw_list,"sentiment")
names= pc.index
size=pc["Percentage"]
 
# Create a circle for the center of the plot
my_circle=plt.Circle( (0,0), 0.7, color='white')
plt.pie(size, labels=names, colors=['green','blue','red'])
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.show()

# %%
#Function to Create Wordcloud

def create_wordcloud(text):
    stopwords = set(STOPWORDS)
    wc = WordCloud(background_color="white", width=600, height=400,               
                  max_words=300,
                  stopwords=stopwords,
                  repeat=True)
    wc.generate(str(text))
    
    plt.imshow(wc)
    plt.show()

# %%
#Creating wordcloud for all tweets
create_wordcloud(tw_list["text"].values)

# %%
#Creating wordcloud for positive sentiment
create_wordcloud(tw_list_positive["text"].values)

# %%
#Creating wordcloud for negative sentiment
create_wordcloud(tw_list_negative["text"].values)

# %%
#Creating wordcloud for neutral sentiment
create_wordcloud(tw_list_neutral["text"].values)
